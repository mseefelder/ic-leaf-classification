# %% [markdown]
# # Relatório Preliminar: *Leaf classification*
#
# * Disciplina:
#  * Inteligência Computacional
# * Profesor:
#     * Alexandre Gonçalves Evsukoff
# * Alunos:
#     * Celso Teixeira Tinoco
#     * Marcos Seefelder de Assis Araujo

# %% [markdown]
# ## Introdução:
#
# [Falar que o objetivo do trabalho é desenvolver os conhecimentos de inteligência computacional através da prática]
# [Falar que o objetivo do relatório preliminar é apresentar o problema e analisá-lo, discutindo suas características]
# [Explicar o que é a classificação de folhas de uma maneira bem geral]
# [Explicar quais as seções do trablho e o que vai ser feito em cada]

# %% [markdown]
# ## Caracterização:
#
# Nessa seção iremos analisar e pré-processar o conjunto de dados obtido para o desenvolvimento do projeto. O mesmo é um conjunto fornecido para uma das competições listadas na plataforma [Kaggle](https://www.kaggle.com/competitions).
#
# Comentários sobre as nossas conclusões em relação ao mesmo serão adicionados ao longo da seção, seguidos dos testes feitos.
#
# As análises feitas serão:
# [listar...]

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
train = pd.read_csv('train.csv')
train = train.drop(['species', 'id'], axis=1)

# %%
figure(figsize=(12,6))
mat = matshow(train.corr(), cmap='jet')
colorbar(mat);

# %%
figure(figsize=(12,6))
mat = matshow(train.cov(), cmap='jet')
colorbar(mat);

# %%
train.describe()
# Out:
#           margin1     margin2     margin3     margin4     margin5     margin6  \
# count  990.000000  990.000000  990.000000  990.000000  990.000000  990.000000
# mean     0.017412    0.028539    0.031988    0.023280    0.014264    0.038579
# std      0.019739    0.038855    0.025847    0.028411    0.018390    0.052030
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.001953    0.001953    0.013672    0.005859    0.001953    0.000000
# 50%      0.009766    0.011719    0.025391    0.013672    0.007812    0.015625
# 75%      0.025391    0.041016    0.044922    0.029297    0.017578    0.056153
# max      0.087891    0.205080    0.156250    0.169920    0.111330    0.310550
#
#           margin7     margin8     margin9    margin10     ...       texture55  \
# count  990.000000  990.000000  990.000000  990.000000     ...      990.000000
# mean     0.019202    0.001083    0.007167    0.018639     ...        0.036501
# ...

# %%
figure(figsize(12,6))
title("Análise do vetor de margin")
train.ix[:,'margin1':'margin64'].boxplot()

figure(figsize(12,6))
title("Análise do vetor de shape")
train.ix[:,'shape1':'shape64'].boxplot()

figure(figsize(12,6))
title("Análise do vetor de texture")
train.ix[:,'texture1':'texture64'].boxplot()

# %%
figure(figsize(12,6))
train.ix[:,'shape1':'shape64'].hist();

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(train.ix[:,'shape1':'shape10'], alpha=0.2, figsize=(12, 12), diagonal='kde');
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-4f53c19bbe03> in <module>()
#       1 from pandas.tools.plotting import scatter_matrix
# ----> 2 scatter_matrix(train.ix[:,'shape1':'shape64'], alpha=0.2, figsize=(12, 12), diagonal='kde');
#
# /home/mseefelder/local/main-venv/lib/python3.5/site-packages/pandas/tools/plotting.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwds)
#     347     naxes = n * n
#     348     fig, axes = _subplots(naxes=naxes, figsize=figsize, ax=ax,
# --> 349                           squeeze=False)
#     350
#     351     # no gaps between subplots
#
# /home/mseefelder/local/main-venv/lib/python3.5/site-packages/pandas/tools/plotting.py in _subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
# ...
